# %% [markdown]
# <h1><font color='green'><Welcome to The Artificial Intelligence with Python Class</font></h1>
#     [image.png](attachment:d74a8c31-9fec-4e95-b8b0-e546026781f4.png)![image.png](attachment:c45ad10c-8ace-4537-a527-f12f6a44f465.png)

# %%
print('This is my First class in "Aritificial Intelligence with Python"
# Out:
#   Cell In[3], line 1
#     print('This is my First class in "Aritificial Intelligence with Python"
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('This is my First class in "Artificial Intelligence with Python"!!!')
# Out:
# This is my First class in "Artificial Intelligence with Python"!!!
