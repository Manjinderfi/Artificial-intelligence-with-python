# %% [markdown]
# ![image.png](attachment:b78ed79e-2f3b-4c71-a9a5-c2c3a5343878.png)![image.png](attachment:8ffe597d-2df8-4be0-b02b-41e5baf12d62.png)

# %% [markdown]
# <h1><font color='green'><imgWelcome to The Artificial Intelligence with Python Class</font></h1>
